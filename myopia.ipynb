# %%
#Import dependancies.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Part 1: Prepare the Data.

# %%
#Import the data.
file_path = Path("myopia.csv")
myopia_df = pd.read_csv(file_path)
myopia_df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# ...

# %%
#Previews the DataFrame.
myopia_df.head(5)
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# 2        0    10         14      0      0       0
# 3        0     4         37      0      1       1
# 4        0     4          4      1      0       0

# %%
#Remove the "MYOPIC" column from the dataset.
myopia_data= myopia_df.drop(["MYOPIC"], axis="columns")
myopia_data
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# 0          0    10         34      1      1
# ...

# %%
#Checking null/missing values.
myopia_data.isnull().sum()
# Out:
# AGE          0
# SPHEQ        0
# AL           0
# ACD          0
# LT           0
# VCD          0
# SPORTHR      0
# READHR       0
# COMPHR       0
# STUDYHR      0
# TVHR         0
# DIOPTERHR    0
# MOMMY        0
# DADMY        0
# dtype: int64

# %%
#Check Data Types.
myopia_data.dtypes
# Out:
# AGE            int64
# SPHEQ        float64
# AL           float64
# ACD          float64
# LT           float64
# VCD          float64
# SPORTHR        int64
# READHR         int64
# COMPHR         int64
# STUDYHR        int64
# TVHR           int64
# DIOPTERHR      int64
# MOMMY          int64
# DADMY          int64
# dtype: object

# %%
#Check for Duplicates.
myopia_data.duplicated().sum()
# Out:
# 0

# %%
#Standardize dataset.
scaler = StandardScaler()
scaled_data = scaler.fit_transform(myopia_data)
print(scaled_data[0:5])
# Out:
# [[-0.42021911 -1.3639169  -0.89286146  0.48378402 -0.28144315 -1.0197916
#    4.1506609   1.69744958 -0.68931054 -0.67299591  0.18405806  0.49830393
#    0.98713773  1.0032415 ]
#  [-0.42021911 -0.30861224 -0.1718398   0.53591028 -0.96799728 -0.13076253
#   -0.99889822 -0.91206246 -0.36187479 -0.22140908 -0.34093217 -0.87508755
#    0.98713773  1.0032415 ]
#  [-0.42021911  0.60438629 -0.00997682 -0.5066285  -0.17781207  0.21580879
#    0.25709181 -0.91206246 -0.03443904 -0.67299591  0.18405806 -0.75023378
#   -1.01302987 -0.99676897]
#  [-0.42021911 -0.4413248  -0.43670267  1.23093648  0.4569273  -0.97458715
#    0.75948782  2.6760166  -0.68931054 -0.67299591 -0.86592239  0.68558458
#   -1.01302987  1.0032415 ]
#  [-1.82397807 -0.16630592  1.16720365  0.42296952 -0.56642745  1.18017813
#    0.25709181 -0.91206246 -0.68931054 -0.67299591 -0.86592239 -1.37450264
#    0.98713773 -0.99676897]]

# %%
#Create a DataFrame with the transformed data.
scaled_myopia = pd.DataFrame(scaled_data, columns=myopia_data.columns)
scaled_myopia.head()
# Out:
#         AGE     SPHEQ        AL       ACD        LT       VCD   SPORTHR  \
# 0 -0.420219 -1.363917 -0.892861  0.483784 -0.281443 -1.019792  4.150661
# 1 -0.420219 -0.308612 -0.171840  0.535910 -0.967997 -0.130763 -0.998898
# 2 -0.420219  0.604386 -0.009977 -0.506628 -0.177812  0.215809  0.257092
# 3 -0.420219 -0.441325 -0.436703  1.230936  0.456927 -0.974587  0.759488
# 4 -1.823978 -0.166306  1.167204  0.422970 -0.566427  1.180178  0.257092
#
#      READHR    COMPHR   STUDYHR      TVHR  DIOPTERHR     MOMMY     DADMY
# 0  1.697450 -0.689311 -0.672996  0.184058   0.498304  0.987138  1.003241
# 1 -0.912062 -0.361875 -0.221409 -0.340932  -0.875088  0.987138  1.003241
# 2 -0.912062 -0.034439 -0.672996  0.184058  -0.750234 -1.013030 -0.996769
# 3  2.676017 -0.689311 -0.672996 -0.865922   0.685585 -1.013030  1.003241
# 4 -0.912062 -0.689311 -0.672996 -0.865922  -1.374503  0.987138 -0.996769

# %% [markdown]
# # Part 2: Apply Dimensionality Reduction.

# %%
#Perform dimensionality reduction with PCA. 
#Initialize PCA model.
pca = PCA(n_components=0.90)

# %%
#Get principle components. 
pca_transformed_data = pca.fit_transform(scaled_myopia)

# %%
#Fetch the explained variance.
pca.explained_variance_ratio_
# Out:
# array([0.21177355, 0.15659716, 0.08688023, 0.08301762, 0.07584858,
#        0.06997878, 0.06486986, 0.06377808, 0.05393666, 0.05205566])

# %%
#sum of explained variance.
print("Explained variance ratio:", pca.explained_variance_ratio_.sum())
print("The larger the variance explained by PCA,the more important that component is.")
# Out:
# Explained variance ratio: 0.9187361702915189
# The larger the variance explained by PCA,the more important that component is.

# %%
#Get the shape of features after reduction.
pca_transformed_data.shape
# Out:
# (618, 10)

# %%
#Transform PCA data to a DataFrame.
myopia_pca = pd.DataFrame(data=pca_transformed_data,columns=["Principal Component 1", "Principal Component 2", "Principal Component 3",\
                                                             "Principal Component4","Principal Component 5", "Principal Component 6",\
                                                             "Principal Component 7", "Principal Component 8","Principal Component 9", "Principal Component 10"],
)
myopia_pca.head()
# Out:
#    Principal Component 1  Principal Component 2  Principal Component 3  \
# 0               0.535503               1.145004              -1.385019
# 1              -0.624706              -1.575786              -0.794253
# 2              -0.933479              -0.717076               0.820150
# 3               0.106354               1.192475              -0.024441
# 4              -0.388503              -2.839655              -0.229767
#
#    Principal Component4  Principal Component 5  Principal Component 6  \
# 0              0.116006              -3.226691              -1.928459
# 1              1.156287               0.292256               0.349060
# 2             -1.547638               0.173941               0.272783
# 3              1.507469              -2.356836              -0.023139
# 4             -0.622510               0.271458              -0.928956
#
#    Principal Component 7  Principal Component 8  Principal Component 9  \
# ...

# %%
#Initializing TSNE model.
tsne = TSNE(learning_rate=200)
#Reducing dimensions.
tsne_features = tsne.fit_transform(myopia_pca)
tsne_features
# Out:
# array([[ 17.117594 ,   0.438539 ],
#        [ -8.904172 , -22.009441 ],
#        [ -5.2400603,   9.674894 ],
#        ...,
#        [ -8.768706 , -20.209055 ],
#        [  3.229704 ,  12.341402 ],
#        [ -6.1811814, -17.110247 ]], dtype=float32)

# %%
#Check that dimensions have been reduced to two.
tsne_features.shape
# Out:
# (618, 2)

# %%
#Create a scatter plot of the t-SNE output.
plt.scatter(tsne_features[:,0], tsne_features[:,1])
plt.show()

# %% [markdown]
# # Part 3: Perform a Cluster Analysis with K-means.

# %%
#Use a for loop to determine the inertia for each k between 1 through 10.
inertia = []
k = list(range(1, 11))

for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(myopia_pca)
    inertia.append(km.inertia_)

elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head()
# Out:
#    k      inertia
# 0  1  7948.905345
# 1  2  6794.415695
# 2  3  6031.097742
# 3  4  5662.587617
# 4  5  5376.410589

# %%
#Create an elbow plot.
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for myopia')
plt.show()

# %%
#Create an elbow plot to identify the best number of clusters.
def get_clusters(k, data):
     #Initialize the K-Means model.
    model = KMeans(n_clusters=k, random_state=0)
    #Train the model.
    model.fit(data)
    #Predict clusters.
    predictions = model.predict(data)
    #Return data.
    data["class"] = model.labels_

    return data

# %%
#Analyzing Clusters with the Best Value of k.
clusters = get_clusters(3, myopia_pca)
clusters
# Out:
#      Principal Component 1  Principal Component 2  Principal Component 3  \
# 0                 0.535503               1.145004              -1.385019
# 1                -0.624706              -1.575786              -0.794253
# 2                -0.933479              -0.717076               0.820150
# 3                 0.106354               1.192475              -0.024441
# 4                -0.388503              -2.839655              -0.229767
# ..                     ...                    ...                    ...
# 613              -0.237547               1.146547              -1.546054
# 614              -0.649011              -1.796952              -0.823592
# 615              -0.890082              -2.308005               0.268102
# 616              -1.124000               0.451890               0.001659
# 617              -0.691534              -0.737046              -1.052900
#
#      Principal Component4  Principal Component 5  Principal Component 6  \
# ...

# %%
def show_clusters(myopia_pca):
    plt.scatter(myopia_pca['Principal Component 1'], myopia_pca['Principal Component 2'], 
                c=myopia_pca['class'])
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.show()
show_clusters(clusters)

# %% [markdown]
# # Part 4: Make a Recommendation.

# %% [markdown]
# Based on the K-means model the elbow point is at k=3 which shows that patients can be clustered together into 3 clusters.
